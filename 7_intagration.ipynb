# %% [markdown]
# ## In this part, i'll try to integrate images together using the binning info.
#
# I'll also try to use galfit to get an effective radius and psf reduction.

# %%
from   astropy.table import Table
import matplotlib.pyplot as plt

bin_label_m = ['8<logm<9.75','9.75<logm<10.5','10.5<logm<11.25']
bin_label_z = ['0.7<z<1.1','1.1<z<1.5']
obj_lis = Table.read('obj_lis_selected_bins.fits')

# %%
# Out:
# <Table length=38>
#   ID          RA               DEC         ...    pixel_length    bin_m bin_z
#                                            ...
# int32      float64           float64       ...      float64       int64 int64
# ----- ----------------- ------------------ ... ------------------ ----- -----
# 11228      189.22685545  62.19790202999998 ... 0.8269988889942779     1     1
# 11839      189.12358402       62.200011467 ... 0.8554636657846902     1     2
# 11883      189.15202702  62.20081933799998 ... 0.8182658962789189     1     1
# 12769       189.1234812  62.20575567000002 ... 0.7963001111396228     1     1
# 13909       189.1095195  62.21083229799999 ... 0.8554612622287284     1     2
# 15761      189.11433023  62.21985369900001 ...  0.853755742834964     1     2
# 17829      189.15263956  62.22966828799999 ... 0.8145016912627409     1     1
# 17927      189.10311597  62.23017693300001 ... 0.8628997673936062     1     2
# 18315      189.21959023  62.23202300300001 ... 0.8633969747548595     1     2
#   ...               ...                ... ...                ...   ...   ...
# 29846 53.14799973053298 -27.77467204575952 ... 0.8398438938518262     1     1
# 36182 53.16025349999958 -27.74326604400006 ... 0.8152201670533331     1     1
# 37010      53.148766524 -27.73888486099999 ... 0.8094107345613432     1     1
# 38616 53.09981077363921 -27.73030119520095 ... 0.8607302810271469     1     2
# 40078       53.05561582 -27.72343869400001 ... 0.8597814657703742     1     2
# 40620      53.155506098      -27.720811117 ... 0.7997691800143771     1     1
# 40976 53.09868232993566 -27.71908677835889 ... 0.8192580918073484     1     1
# 41122 53.12833327907151 -27.71841308433602 ...  0.868978721932518     1     2
# 46464      53.236739918      -27.692590973 ... 0.8445995090530664     1     2
# 46685      53.241491656 -27.69098539100001 ... 0.8558481260990382     1     2
